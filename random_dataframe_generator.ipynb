# %%
import random
import string
from sklearn.datasets import make_blobs
import pandas as pd
def create_synthetic_data(n_customers=20, max_orders=20, max_items=10):

  '''Function to create synthetic data'''


  headers = []
  datalist = []

  for customer in range(1,n_customers):
    
    for _ in range(1,random.randrange(1,max_orders)):
        order_number = ''.join(random.choices(str(customer) + string.ascii_letters + string.digits, k=16))

        # for item in range(1,random.randrange(1,max_items)):
        #     headers.append([f'customer_{customer}', f'{order_number}' , f'{item}'])
        #     print(headers)
        item_list = range(1,random.randrange(2,max_items))
        headers.append([f'customer_{customer}', f'{order_number}' , f'{[random.choice(item_list) for _ in item_list ]}'])
    datalist.append(headers)
  s
#   blobs = make_blobs(n_samples=len(headers), n_features=3, random_state=42)

#   [h.extend([round(100*(b+15), 2) for b in blob]) for h, blob in zip(headers, blobs[0])]

  columns = ['customer_id', 'order_id', 'item_list'] 

  return pd.DataFrame(datalist[0], columns=columns)








data= create_synthetic_data(

    n_customers=10, 

    max_orders= 5,

    max_items= 10)
# Out:
# [[['customer_1', 'PZL9nB7QfvVD6ijA', '[2, 4, 1, 2, 3]'], ['customer_1', 'KNeaGwvajW75mKHi', '[4, 2, 5, 8, 2, 7, 5, 5]'], ['customer_2', 'fOHwiY94nlWS57PR', '[2, 1, 1]'], ['customer_2', 'dJXePlJGI2OD6MCf', '[1, 2]'], ['customer_2', 'dVVf42jKNHv9E6GF', '[3, 3, 3]'], ['customer_3', 'iRh3HzBbJrcWkvAB', '[1]'], ['customer_3', 'YtW4HFqsR3XJn7LQ', '[2, 1]'], ['customer_4', 'SS6BfFpIVtUWMz65', '[2, 4, 1, 1]'], ['customer_4', 'ANzEoSS1YT05y1mG', '[1, 7, 4, 7, 4, 2, 2]'], ['customer_4', 'loiOZGIRoTkR2JZs', '[1]'], ['customer_7', 'Rcg2z8CcXTvNDp5D', '[3, 2, 3, 4, 1]'], ['customer_7', 'Q6Bzshw2Ql5mzZzy', '[1]'], ['customer_7', 'HelgQ1Vx7KyfCqV7', '[2, 3, 1]'], ['customer_8', 'vbu8fGT5oWndOZof', '[5, 6, 5, 5, 1, 1, 6]']], [['customer_1', 'PZL9nB7QfvVD6ijA', '[2, 4, 1, 2, 3]'], ['customer_1', 'KNeaGwvajW75mKHi', '[4, 2, 5, 8, 2, 7, 5, 5]'], ['customer_2', 'fOHwiY94nlWS57PR', '[2, 1, 1]'], ['customer_2', 'dJXePlJGI2OD6MCf', '[1, 2]'], ['customer_2', 'dVVf42jKNHv9E6GF', '[3, 3, 3]'], ['customer_3', 
# ...

# %%
item_list = range(1,10)
item_choice = random.choice(item_list)
print(item_choice)
print([random.choice(item_list) for _ in item_list])
# Out:
# 4
# [3, 2, 6, 7, 1, 9, 2, 3, 5]

# %%
data
# Out:
#    customer_id          order_id                 item_list
# 0   customer_1  PZL9nB7QfvVD6ijA           [2, 4, 1, 2, 3]
# 1   customer_1  KNeaGwvajW75mKHi  [4, 2, 5, 8, 2, 7, 5, 5]
# 2   customer_2  fOHwiY94nlWS57PR                 [2, 1, 1]
# 3   customer_2  dJXePlJGI2OD6MCf                    [1, 2]
# 4   customer_2  dVVf42jKNHv9E6GF                 [3, 3, 3]
# 5   customer_3  iRh3HzBbJrcWkvAB                       [1]
# 6   customer_3  YtW4HFqsR3XJn7LQ                    [2, 1]
# 7   customer_4  SS6BfFpIVtUWMz65              [2, 4, 1, 1]
# 8   customer_4  ANzEoSS1YT05y1mG     [1, 7, 4, 7, 4, 2, 2]
# 9   customer_4  loiOZGIRoTkR2JZs                       [1]
# 10  customer_7  Rcg2z8CcXTvNDp5D           [3, 2, 3, 4, 1]
# 11  customer_7  Q6Bzshw2Ql5mzZzy                       [1]
# 12  customer_7  HelgQ1Vx7KyfCqV7                 [2, 3, 1]
# 13  customer_8  vbu8fGT5oWndOZof     [5, 6, 5, 5, 1, 1, 6]
